# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
steps = pd.read_csv("steps.csv", index_col = "id")
providers = pd.read_csv("internetProviders.csv", index_col = "Provider_Id")

# %%
steps.groupby("neighborhood").sum()['number_of_steps'].sort_values(ascending=False)
# Out:
# neighborhood
# South Side Slopes           3666.0
# Beechview                   2400.0
# Perry South                 1798.0
# Hazelwood                   1373.0
# Greenfield                  1305.0
# Marshall-Shadeland          1210.0
# Troy Hill                   1115.0
# Brookline                   1114.0
# Fineview                    1110.0
# Mount Washington            1087.0
# Overbrook                   1012.0
# Polish Hill                  982.0
# Spring Hill-City View        946.0
# Elliott                      933.0
# Sheraden                     887.0
# Perry North                  846.0
# Carrick                      794.0
# California-Kirkbride         742.0
# Upper Lawrenceville          713.0
# Stanton Heights              671.0
# Garfield                     606.0
# Upper Hill                   593.0
# Homewood North               565.0
# Spring Garden                526.0
# Lincoln-Lemington-Belmar     495.0
# Brighton Heights             487.0
# East Allegheny               487.0
# Middle Hill                  487.0
# West Oakland                 485.0
# Crafton Heights              478.0
#                              ...
# Lincoln Place                248.0
# Bedford Dwellings            234.0
# Banksville                   224.0
# Bluff                        179.0
# Bloomfield                   161.0
# Point Breeze                 156.0
# Knoxville                    151.0
# Glen Hazel                   151.0
# East Hills                   140.0
# Oakwood                      129.0
# West End                     127.0
# Terrace Village              106.0
# Squirrel Hill South          105.0
# Larimer                       93.0
# Mt. Oliver                    89.0
# Crawford-Roberts              88.0
# Chartiers City                81.0
# Ridgemont                     76.0
# North Oakland                 72.0
# Highland Park                 66.0
# Strip District                65.0
# Bon Air                       57.0
# South Side Flats              56.0
# Esplen                        54.0
# East Carnegie                 52.0
# St. Clair                     26.0
# Windgap                       16.0
# Central Lawrenceville          9.0
# Mount Oliver Borough           9.0
# Shadyside                      0.0
# Name: number_of_steps, Length: 70, dtype: float64

# %%
stepsDF = steps.groupby('neighborhood').sum()
stepsDF = stepsDF.sort_values(['number_of_steps'], ascending = [False])
stepsDF = stepsDF.filter(items = ['name', 'number_of_steps', 'neighborhood'])
stepsDF
# Out:
#                           number_of_steps
# neighborhood
# South Side Slopes                  3666.0
# Beechview                          2400.0
# Perry South                        1798.0
# Hazelwood                          1373.0
# Greenfield                         1305.0
# Marshall-Shadeland                 1210.0
# Troy Hill                          1115.0
# Brookline                          1114.0
# Fineview                           1110.0
# Mount Washington                   1087.0
# Overbrook                          1012.0
# Polish Hill                         982.0
# Spring Hill-City View               946.0
# Elliott                             933.0
# Sheraden                            887.0
# Perry North                         846.0
# Carrick                             794.0
# California-Kirkbride                742.0
# Upper Lawrenceville                 713.0
# Stanton Heights                     671.0
# Garfield                            606.0
# Upper Hill                          593.0
# Homewood North                      565.0
# Spring Garden                       526.0
# Lincoln-Lemington-Belmar            495.0
# East Allegheny                      487.0
# Brighton Heights                    487.0
# Middle Hill                         487.0
# West Oakland                        485.0
# Crafton Heights                     478.0
# ...                                   ...
# Lincoln Place                       248.0
# Bedford Dwellings                   234.0
# Banksville                          224.0
# Bluff                               179.0
# Bloomfield                          161.0
# Point Breeze                        156.0
# Knoxville                           151.0
# Glen Hazel                          151.0
# East Hills                          140.0
# Oakwood                             129.0
# West End                            127.0
# Terrace Village                     106.0
# Squirrel Hill South                 105.0
# Larimer                              93.0
# Mt. Oliver                           89.0
# Crawford-Roberts                     88.0
# Chartiers City                       81.0
# Ridgemont                            76.0
# North Oakland                        72.0
# Highland Park                        66.0
# Strip District                       65.0
# Bon Air                              57.0
# South Side Flats                     56.0
# Esplen                               54.0
# East Carnegie                        52.0
# St. Clair                            26.0
# Windgap                              16.0
# Central Lawrenceville                 9.0
# Mount Oliver Borough                  9.0
# Shadyside                             0.0
#
# [70 rows x 1 columns]

# %%
stepsDF['metric'] = stepsDF['number_of_steps']/3666.0
stepsDF
# Out:
#                           number_of_steps    metric
# neighborhood
# South Side Slopes                  3666.0  1.000000
# Beechview                          2400.0  0.654664
# Perry South                        1798.0  0.490453
# Hazelwood                          1373.0  0.374523
# Greenfield                         1305.0  0.355974
# Marshall-Shadeland                 1210.0  0.330060
# Troy Hill                          1115.0  0.304146
# Brookline                          1114.0  0.303873
# Fineview                           1110.0  0.302782
# Mount Washington                   1087.0  0.296508
# Overbrook                          1012.0  0.276050
# Polish Hill                         982.0  0.267867
# Spring Hill-City View               946.0  0.258047
# Elliott                             933.0  0.254501
# Sheraden                            887.0  0.241953
# Perry North                         846.0  0.230769
# Carrick                             794.0  0.216585
# California-Kirkbride                742.0  0.202400
# Upper Lawrenceville                 713.0  0.194490
# Stanton Heights                     671.0  0.183033
# Garfield                            606.0  0.165303
# Upper Hill                          593.0  0.161757
# Homewood North                      565.0  0.154119
# Spring Garden                       526.0  0.143481
# Lincoln-Lemington-Belmar            495.0  0.135025
# East Allegheny                      487.0  0.132842
# Brighton Heights                    487.0  0.132842
# Middle Hill                         487.0  0.132842
# West Oakland                        485.0  0.132297
# Crafton Heights                     478.0  0.130387
# ...                                   ...       ...
# Lincoln Place                       248.0  0.067649
# Bedford Dwellings                   234.0  0.063830
# Banksville                          224.0  0.061102
# Bluff                               179.0  0.048827
# Bloomfield                          161.0  0.043917
# Point Breeze                        156.0  0.042553
# Knoxville                           151.0  0.041189
# Glen Hazel                          151.0  0.041189
# East Hills                          140.0  0.038189
# Oakwood                             129.0  0.035188
# West End                            127.0  0.034643
# Terrace Village                     106.0  0.028914
# Squirrel Hill South                 105.0  0.028642
# Larimer                              93.0  0.025368
# Mt. Oliver                           89.0  0.024277
# Crawford-Roberts                     88.0  0.024004
# Chartiers City                       81.0  0.022095
# Ridgemont                            76.0  0.020731
# North Oakland                        72.0  0.019640
# Highland Park                        66.0  0.018003
# Strip District                       65.0  0.017730
# Bon Air                              57.0  0.015548
# South Side Flats                     56.0  0.015276
# Esplen                               54.0  0.014730
# East Carnegie                        52.0  0.014184
# St. Clair                            26.0  0.007092
# Windgap                              16.0  0.004364
# Central Lawrenceville                 9.0  0.002455
# Mount Oliver Borough                  9.0  0.002455
# Shadyside                             0.0  0.000000
#
# [70 rows x 2 columns]

# %%
plt.style.use('seaborn')
stepsDF["number_of_steps"].plot.bar(figsize = (30, 4))

# %%
providers.head()
# Out:
#             Neighborhood         GEOID  LogRecNo      FRN  \
# Provider_Id
# 20901              Bluff  420030103002    257484  4335584
# 20901              Bluff  420030103002    257485  4335584
# 20901              Bluff  420030103002    257486  4335584
# 20901              Bluff  420030103002    257487  4335584
# 20901              Bluff  420030103003    257488  4335584
#
#                                ProviderName DBAName  \
# Provider_Id
# 20901        MCI Communications Corporation     MCI
# 20901        MCI Communications Corporation     MCI
# 20901        MCI Communications Corporation     MCI
# 20901        MCI Communications Corporation     MCI
# 20901        MCI Communications Corporation     MCI
#
#                       HoldingCompanyName  HocoNum  \
# Provider_Id
# 20901        Verizon Communications Inc.   131425
# 20901        Verizon Communications Inc.   131425
# 20901        Verizon Communications Inc.   131425
# 20901        Verizon Communications Inc.   131425
# 20901        Verizon Communications Inc.   131425
#
#                                HocoFinal StateAbbr        BlockCode  TechCode  \
# Provider_Id
# 20901        Verizon Communications Inc.        PA  420030103002001        30
# 20901        Verizon Communications Inc.        PA  420030103002012        30
# 20901        Verizon Communications Inc.        PA  420030103002017        30
# 20901        Verizon Communications Inc.        PA  420030103002019        30
# 20901        Verizon Communications Inc.        PA  420030103003004        30
#
#              Consumer  MaxAdDown  MaxAdUp  Business  MaxCIRDown  MaxCIRUp
# Provider_Id
# 20901               0        0.0      0.0         1         3.0       3.0
# 20901               0        0.0      0.0         1         1.5       1.5
# 20901               0        0.0      0.0         1         1.5       1.5
# 20901               0        0.0      0.0         1         3.0       3.0
# 20901               0        0.0      0.0         1         3.0       3.0

# %%
providersDF = providers.filter(items = ['Neighborhood', 'MaxAdDown', 'MaxAdUp'])
providersDF = providersDF.groupby("Neighborhood").sum().sort_values(['MaxAdDown'], ascending = False)
providersDF['metricDown'] = providersDF['MaxAdDown']/80796.768
providersDF['metricUp'] = providersDF['MaxAdUp']/32158.964

providersDF
# Out:
#                           MaxAdDown    MaxAdUp  metricDown  metricUp
# Neighborhood
# Carrick                   80796.768  32158.964    1.000000  1.000000
# Brookline                 76581.000  29822.028    0.947823  0.927332
# Mount Washington          64498.500  25170.600    0.798281  0.782693
# Sheraden                  55776.000  22292.852    0.690325  0.693208
# South Side Flats          53871.000  21137.792    0.666747  0.657291
# Bloomfield                53671.000  20920.652    0.664272  0.650539
# Shadyside                 47050.500  18396.300    0.582331  0.572043
# Squirrel Hill South       45495.000  17546.108    0.563079  0.545606
# Brighton Heights          44685.500  17606.844    0.553060  0.547494
# Greenfield                43041.000  16490.584    0.532707  0.512783
# Beechview                 42069.500  16394.560    0.520683  0.509798
# Hazelwood                 41807.500  16795.276    0.517440  0.522258
# Central Lawrenceville     40008.536  15276.216    0.495175  0.475022
# Beltzhoover               39348.500  15372.272    0.487006  0.478009
# Elliott                   39076.000  15351.656    0.483633  0.477368
# South Side Slopes         38889.000  15325.612    0.481319  0.476558
# Highland Park             38603.000  14859.744    0.477779  0.462072
# Perry South               38387.000  14767.832    0.475106  0.459214
# Lincoln-Lemington-Belmar  38162.000  14895.368    0.472321  0.463179
# Homewood South            37605.500  15035.208    0.465433  0.467528
# Knoxville                 34915.500  13794.256    0.432140  0.428940
# Marshall-Shadeland        34438.768  13367.160    0.426239  0.415659
# Allentown                 32635.500  12592.220    0.403921  0.391562
# Central Northside         32543.000  12558.672    0.402776  0.390519
# Point Breeze              32197.000  12317.932    0.398494  0.383033
# East Liberty              32020.500  12521.264    0.396309  0.389355
# Overbrook                 31618.000  12541.100    0.391328  0.389972
# Lincoln Place             30806.500  12343.892    0.381284  0.383840
# Squirrel Hill North       29515.500  11175.580    0.365305  0.347511
# Larimer                   29155.000  11496.140    0.360844  0.357479
# ...                             ...        ...         ...       ...
# Regent Square             10923.500   4425.364    0.135197  0.137609
# Esplen                    10362.000   4202.680    0.128248  0.130685
# Spring Garden             10026.500   3935.520    0.124095  0.122377
# East Carnegie              9955.000   4011.776    0.123210  0.124748
# Swisshelm Park             9687.000   3881.976    0.119893  0.120712
# Point Breeze North         9473.500   4136.680    0.117251  0.128632
# West Oakland               9220.500   2916.276    0.114120  0.090683
# Summer Hill                9131.500   3387.864    0.113018  0.105347
# Polish Hill                9093.500   3759.568    0.112548  0.116906
# Windgap                    8628.000   3493.352    0.106786  0.108628
# West End                   8081.500   3219.644    0.100023  0.100117
# North Shore                7659.000   2238.560    0.094793  0.069609
# Friendship                 7396.000   3017.336    0.091538  0.093826
# Terrace Village            7048.000   1730.920    0.087231  0.053824
# Bon Air                    6658.000   2605.220    0.082404  0.081011
# Chartiers City             6079.768   2363.004    0.075248  0.073479
# Hays                       6004.500   2231.212    0.074316  0.069381
# Northview Heights          5550.000   1996.780    0.068691  0.062091
# Allegheny West             5527.000   2047.804    0.068406  0.063678
# Mt. Oliver                 5193.000   2096.612    0.064272  0.065195
# Bedford Dwellings          4715.500   1707.116    0.058362  0.053084
# Oakwood                    4355.000   1749.336    0.053901  0.054397
# Fairywood                  3974.000   1381.568    0.049185  0.042961
# Chateau                    3434.500   1250.996    0.042508  0.038900
# St. Clair                  3017.000   1192.564    0.037341  0.037083
# Allegheny Center           2782.000    721.388    0.034432  0.022432
# Ridgemont                  2480.000    951.836    0.030694  0.029598
# South Shore                2393.000    681.012    0.029618  0.021176
# Glen Hazel                 1959.500    752.488    0.024252  0.023399
# Arlington Heights          1012.000    369.336    0.012525  0.011485
#
# [91 rows x 4 columns]

# %%
providersDF["MaxAdUp"].plot.bar(figsize = (25, 4))

# %%
stepsDF.index
# Out:
# Index(['South Side Slopes', 'Beechview', 'Perry South', 'Hazelwood',
#        'Greenfield', 'Marshall-Shadeland', 'Troy Hill', 'Brookline',
#        'Fineview', 'Mount Washington', 'Overbrook', 'Polish Hill',
#        'Spring Hill-City View', 'Elliott', 'Sheraden', 'Perry North',
#        'Carrick', 'California-Kirkbride', 'Upper Lawrenceville',
#        'Stanton Heights', 'Garfield', 'Upper Hill', 'Homewood North',
#        'Spring Garden', 'Lincoln-Lemington-Belmar', 'East Allegheny',
#        'Brighton Heights', 'Middle Hill', 'West Oakland', 'Crafton Heights',
#        'Arlington', 'Central Oakland', 'South Oakland', 'Allentown',
#        'Central Northside', 'Duquesne Heights', 'Beltzhoover', 'Westwood',
#        'Morningside', 'Squirrel Hill North', 'Lincoln Place',
#        'Bedford Dwellings', 'Banksville', 'Bluff', 'Bloomfield',
#        'Point Breeze', 'Knoxville', 'Glen Hazel', 'East Hills', 'Oakwood',
#        'West End', 'Terrace Village', 'Squirrel Hill South', 'Larimer',
#        'Mt. Oliver', 'Crawford-Roberts', 'Chartiers City', 'Ridgemont',
#        'North Oakland', 'Highland Park', 'Strip District', 'Bon Air',
#        'South Side Flats', 'Esplen', 'East Carnegie', 'St. Clair', 'Windgap',
#        'Central Lawrenceville', 'Mount Oliver Borough', 'Shadyside'],
#       dtype='object', name='neighborhood')

# %%
stepsDF.columns
# Out:
# Index(['number_of_steps'], dtype='object')

# %%
stepsDF.values
# Out:
# array([[3666.],
#        [2400.],
#        [1798.],
#        [1373.],
#        [1305.],
#        [1210.],
#        [1115.],
#        [1114.],
#        [1110.],
#        [1087.],
#        [1012.],
#        [ 982.],
#        [ 946.],
#        [ 933.],
#        [ 887.],
#        [ 846.],
#        [ 794.],
#        [ 742.],
#        [ 713.],
#        [ 671.],
#        [ 606.],
#        [ 593.],
#        [ 565.],
#        [ 526.],
#        [ 495.],
#        [ 487.],
#        [ 487.],
#        [ 487.],
#        [ 485.],
#        [ 478.],
#        [ 376.],
#        [ 361.],
#        [ 338.],
#        [ 335.],
#        [ 333.],
#        [ 311.],
#        [ 299.],
#        [ 298.],
#        [ 294.],
#        [ 252.],
#        [ 248.],
#        [ 234.],
#        [ 224.],
#        [ 179.],
#        [ 161.],
#        [ 156.],
#        [ 151.],
#        [ 151.],
#        [ 140.],
#        [ 129.],
#        [ 127.],
#        [ 106.],
#        [ 105.],
#        [  93.],
#        [  89.],
#        [  88.],
#        [  81.],
#        [  76.],
#        [  72.],
#        [  66.],
#        [  65.],
#        [  57.],
#        [  56.],
#        [  54.],
#        [  52.],
#        [  26.],
#        [  16.],
#        [   9.],
#        [   9.],
#        [   0.]])

# %%
stepsDF = stepsDF.sort_values(['neighborhood'], ascending = [True])
stepsDF
# Out:
#                        number_of_steps
# neighborhood
# Allentown                        335.0
# Arlington                        376.0
# Banksville                       224.0
# Bedford Dwellings                234.0
# Beechview                       2400.0
# Beltzhoover                      299.0
# Bloomfield                       161.0
# Bluff                            179.0
# Bon Air                           57.0
# Brighton Heights                 487.0
# Brookline                       1114.0
# California-Kirkbride             742.0
# Carrick                          794.0
# Central Lawrenceville              9.0
# Central Northside                333.0
# Central Oakland                  361.0
# Chartiers City                    81.0
# Crafton Heights                  478.0
# Crawford-Roberts                  88.0
# Duquesne Heights                 311.0
# East Allegheny                   487.0
# East Carnegie                     52.0
# East Hills                       140.0
# Elliott                          933.0
# Esplen                            54.0
# Fineview                        1110.0
# Garfield                         606.0
# Glen Hazel                       151.0
# Greenfield                      1305.0
# Hazelwood                       1373.0
# ...                                ...
# Mount Washington                1087.0
# Mt. Oliver                        89.0
# North Oakland                     72.0
# Oakwood                          129.0
# Overbrook                       1012.0
# Perry North                      846.0
# Perry South                     1798.0
# Point Breeze                     156.0
# Polish Hill                      982.0
# Ridgemont                         76.0
# Shadyside                          0.0
# Sheraden                         887.0
# South Oakland                    338.0
# South Side Flats                  56.0
# South Side Slopes               3666.0
# Spring Garden                    526.0
# Spring Hill-City View            946.0
# Squirrel Hill North              252.0
# Squirrel Hill South              105.0
# St. Clair                         26.0
# Stanton Heights                  671.0
# Strip District                    65.0
# Terrace Village                  106.0
# Troy Hill                       1115.0
# Upper Hill                       593.0
# Upper Lawrenceville              713.0
# West End                         127.0
# West Oakland                     485.0
# Westwood                         298.0
# Windgap                           16.0
#
# [70 rows x 1 columns]

# %%
providersDF = providersDF.sort_values(['Neighborhood'], ascending = [True])
providersDF['number_of_steps'] = stepsDF['number_of_steps']
providersDF = providersDF.sort_values(['MaxAdDown'], ascending = [False])
netAndStepsDF = providersDF.drop(columns = ['metricDown', 'metricUp'])

# %%
netAndStepsDF.plot.bar(stacked = True, figsize = (50, 8))
